# %%
import numpy as np
import torch
from torch import Tensor
from torch import tensor
from torch import nn
from matplotlib import pyplot as plt
import matplotlib as mpl
import torchvision
import json

# %%
loss_grids   = np.load("loss_grids.npy")     # shape: (N, H, W)
trajectories = np.load("trajectories.npy")   # shape: (N, 3) → (x, y, loss)

# %%
loss_grids.shape
# Out:
# (103, 50, 50)

# %%
for i in range(loss_grids.shape[0]):
    plt.imshow(loss_grids[i])
    plt.plot([trajectories[:,0][0:i],trajectories[:,1][0:i]])
    plt.show()
