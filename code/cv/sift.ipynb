# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
imgs = []
for i in range(10):
    img1 = cv.imread(f"../../data/SFM/{i:04d}.jpg",0)
    plt.imshow(img1)
    imgs.append(img1)

# %%
detector = cv.SIFT_create()
FLANN_INDEX_KDTREE = 0
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
search_params = dict(checks = 50)
good_points = []
matcher = cv.FlannBasedMatcher(indexParams=index_params,searchParams=search_params)

for img1 in imgs:
    for img2 in imgs:    
        kp1, des1 = detector.detectAndCompute(img1,None)
        kp2, des2 = detector.detectAndCompute(img2,None)
        matches = matcher.match(des1,des2)
        sorted_matches = sorted(matches, key = lambda x:x.distance)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 14
#      12 matches = matcher.match(des1,des2)
#      13 sorted_matches = sorted(matches, key = lambda x:x.distance)
# ---> 14 for m,n in sorted_matches:
#      15     pass
#
# TypeError: cannot unpack non-iterable cv2.DMatch object

# %%
len(good_points)
# Out:
# 2
